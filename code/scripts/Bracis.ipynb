# %%
import pandas as pd


dados = pd.read_csv('dados_final.csv',index_col="Unnamed: 0")
dados.columns.values
# Out:
# array(['lhm_team', 'lhm_V', 'lhm_D', 'lhm_E', 'lhm_GF', 'lhm_AVG_GF',
#        'lhm_GS', 'lhm_AVG_GS', 'lhm_J1GS', 'lhm_J1GF', 'lhm_BTTS',
#        'lhm_Over2', 'lhm_Over3', 'lhm_Over4', 'lhm_WinningCleanSheet',
#        'lhm_LosingFS', 'lhm_FailedScore', 'lhm_CleanSheet',
#        'lhm_AVG_GOALS', 'ghm_lhm_team', 'ghm_lhm_V', 'ghm_lhm_D',
#        'ghm_lhm_E', 'ghm_lhm_GF', 'ghm_lhm_AVG_GF', 'ghm_lhm_GS',
#        'ghm_lhm_AVG_GS', 'ghm_lhm_J1GS', 'ghm_lhm_J1GF', 'ghm_lhm_BTTS',
#        'ghm_lhm_Over2', 'ghm_lhm_Over3', 'ghm_lhm_Over4',
#        'ghm_lhm_WinningCleanSheet', 'ghm_lhm_LosingFS',
#        'ghm_lhm_FailedScore', 'ghm_lhm_CleanSheet', 'ghm_lhm_AVG_GOALS',
#        'lh_VG', 'lh_DG', 'lh_EG', 'lh_GFG', 'lh_AVG_GFG', 'lh_GSG',
#        'lh_AVG_GSG', 'lh_J1GSG', 'lh_J1GFG', 'lh_BTTSG', 'lh_Over2G',
#        'lh_Over3G', 'lh_Over4G', 'lh_WinningCleanSheetG', 'lh_LosingFSG',
#        'lh_FailedScoreG', 'lh_CleanSheetG', 'lh_AVG_GOALS_G', 'gh_VG',
#        'gh_DG', 'gh_EG', 'gh_GFG', 'gh_AVG_GFG', 'gh_GSG', 'gh_AVG_GSG',
#        'gh_J1GSG', 'gh_J1GFG', 'gh_BTTSG', 'gh_Over2G', 'gh_Over3G',
#        'gh_Over4G', 'gh_WinningCleanSheetG', 'gh_LosingFSG',
#        'gh_FailedScoreG', 'gh_CleanSheetG', 'gh_AVG_GOALS_G', 'lam_V',
#        'lam_D', 'lam_E', 'lam_GF', 'lam_AVG_GF', 'lam_GS', 'lam_AVG_GS',
#        'lam_J1GS', 'lam_J1GF', 'lam_BTTS', 'lam_Over2', 'lam_Over3',
#        'lam_Over4', 'lam_WinningCleanSheet', 'lam_LosingFS',
#        'lam_FailedScore', 'lam_CleanSheet', 'lam_AVG_GOALS', 'gam_team',
#        'gam_V', 'gam_D', 'gam_E', 'gam_GF', 'gam_AVG_GF', 'gam_GS',
#        'gam_AVG_GS', 'gam_J1GS', 'gam_J1GF', 'gam_BTTS', 'gam_Over2',
#        'gam_Over3', 'gam_Over4', 'gam_WinningCleanSheet', 'gam_LosingFS',
#        'gam_FailedScore', 'gam_CleanSheet', 'gam_AVG_GOALS', 'la_VG',
#        'la_DG', 'la_EG', 'la_GFG', 'la_AVG_GFG', 'la_GSG', 'la_AVG_GSG',
#        'la_J1GSG', 'la_J1GFG', 'la_BTTSG', 'la_Over2G', 'la_Over3G',
#        'la_Over4G', 'la_WinningCleanSheetG', 'la_LosingFSG',
#        'la_FailedScoreG', 'la_CleanSheetG', 'la_AVG_GOALS_G', 'ga_team',
#        'ga_VG', 'ga_DG', 'ga_EG', 'ga_GFG', 'ga_AVG_GFG', 'ga_GSG',
#        'ga_AVG_GSG', 'ga_J1GSG', 'ga_J1GFG', 'ga_BTTSG', 'ga_Over2G',
#        'ga_Over3G', 'ga_Over4G', 'ga_WinningCleanSheetG', 'ga_LosingFSG',
#        'ga_FailedScoreG', 'ga_CleanSheetG', 'ga_AVG_GOALS_G',
#        'ga_rank_def', 'ga_rank_atk', 'gh_rank_def', 'gh_rank_atk',
#        'la_rank_def', 'la_rank_atk', 'lh_rank_def', 'lh_rank_atk',
#        'a_date', 'h_date', 'league_id', 'season', 'stage',
#        'home_team_api_id', 'away_team_api_id', 'home_team_goal',
#        'away_team_goal', 'B365H', 'B365D', 'B365A', 'BTTS'], dtype=object)

# %%
def determine_home_result(match):
    if match['home_team_goal'] > match['away_team_goal']:
        return 'H'
    elif match['home_team_goal'] < match['away_team_goal']:
        return 'A'
    else:
        return 'D'
    
    
dados['Output']=dados.apply(determine_home_result, axis=1)

dados = dados.dropna()

-

aux = ['hg_Win','hg_Draw','hg_Losses','hg_GoalScored','hg_avg_GoalScored','hg_GoalSufferd','hg_avg_GoalsSuffered','hg_Matches1GoalScored','hg_Matches1GoalSuffered','hg_WinningsCleanSheet','hg_LosingFailedScore','hg_CleanSheet','hg_avgGoals','hgc_Win','hgc_Draw','hgc_Losses','hgc_GoalScored','hgc_avg_GoalScored','hgc_GoalSufferd','hgc_avg_GoalsSuffered','hgc_Matches1GoalScored','hgc_Matches1GoalSuffered','hgc_WinningsCleanSheet','hgc_LosingFailedScore','hgc_CleanSheet','hgc_avgGoals','hc_Win','hc_Draw','hc_Losses','hc_GoalScored','hc_avg_GoalScored','hc_GoalSufferd','hc_avg_GoalsSuffered','hc_Matches1GoalScored','hc_Matches1GoalSuffered','hc_WinningsCleanSheet','hc_LosingFailedScore','hc_CleanSheet','hc_avgGoals','hlc_Win','hlc_Draw','hlc_Losses','hlc_GoalScored','hlc_avg_GoalScored','hlc_GoalSufferd','hlc_avg_GoalsSuffered','hlc_Matches1GoalScored','hlc_Matches1GoalSuffered','hlc_WinningsCleanSheet','hlc_LosingFailedScore','hlc_CleanSheet','hlc_avgGoals','hl_Win','hl_Draw','hl_Losses','hl_GoalScored','hl_avg_GoalScored','hl_GoalSufferd','hl_avg_GoalsSuffered','hl_Matches1GoalScored','hl_Matches1GoalSuffered','hl_WinningsCleanSheet','hl_LosingFailedScore','hl_CleanSheet','hl_avgGoals','ag_Win','ag_Draw','ag_Losses','ag_GoalScored','ag_avg_GoalScored','ag_GoalSufferd','ag_avg_GoalsSuffered','ag_Matches1GoalScored','ag_Matches1GoalSuffered','ag_WinningsCleanSheet','ag_LosingFailedScore','ag_CleanSheet','ag_avgGoals','agc_Win','agc_Draw','agc_Losses','agc_GoalScored','agc_avg_GoalScored','agc_GoalSufferd','agc_avg_GoalsSuffered','agc_Matches1GoalScored','agc_Matches1GoalSuffered','agc_WinningsCleanSheet','agc_LosingFailedScore','agc_CleanSheet','agc_avgGoals','ac_Win','ac_Draw','ac_Losses','ac_GoalScored','ac_avg_GoalScored','ac_GoalSufferd','ac_avg_GoalsSuffered','ac_Matches1GoalScored','ac_Matches1GoalSuffered','ac_WinningsCleanSheet','ac_LosingFailedScore','ac_CleanSheet','ac_avgGoals','alc_Win','alc_Draw','alc_Losses','alc_GoalScored','alc_avg_GoalScored','alc_GoalSufferd','alc_avgalc_GoalsSuffered','alc_Matches1GoalScored','alc_Matches1GoalSuffered','alc_WinningsCleanSheet','alc_LosingFailedScore','alc_CleanSheet','alc_avgGoals','al_Win','al_Draw','al_Losses','al_GoalScored','al_avgal_GoalScored','al_GoalSufferd','al_avg_GoalsSuffered','al_Matches1GoalScored','al_Matches1GoalSuffered','al_WinningsCleanSheet','al_LosingFailedScore','al_CleanSheet','al_avgGoals','ag_rank_def','ag_rank_atk','hg_rank_def','hg_rank_atk','al_rank_def','al_rank_atk','hl_rank_def','hl_rank_atk','a_date','h_date','B365H','B365D','B365A','hg_Over2Goals','hg_Over3Goals','hg_Over4Goals','hgc_Over2Goals','hgc_Over3Goals','hgc_Over4Goals','hlc_Over2Goals','hlc_Over3Goals','hlc_Over4Goals','hl_Over2Goals','hl_Over3Goals','hl_Over4Goals','hc_Over2Goals','hc_Over3Goals','hc_Over4Goals','ag_Over2Goals','ag_Over3Goals','ag_Over4Goals','agc_Over2Goals','agc_Over3Goals','agc_Over4Goals','alc_Over2Goals','alc_Over3Goals','alc_Over4Goals','al_Over2Goals','al_Over3Goals','al_Over4Goals','ac_Over2Goals','ac_Over3Goals','ac_Over4Goals']


print len(ft)
print len(aux)
dados['league_id'].value_counts()
# Out:
# 160
# 173
# 21518    2640
# 1729     2640
# 4769     2636
# 10257    2609
# 7809     2088
# 13274    2086
# 17642    1714
# Name: league_id, dtype: int64

# %%
dado_aux = dados[dados['league_id'] == 21518]
limit = dado_aux[['league_id','season']]['season'].unique()
train = limit[:-1]
test = limit[-1]
print train
print test
# Out:
# [0 1 2 3 4 5 6]
# 7

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from matplotlib import pyplot as plt

def setRF(X_train,y_train,X_test,y_test):
    n = [50,100,500,1000,2000,3000]
    max = 0
    nmax = 0
    
    for estimator in n :
        rf = RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
        rf.fit(X_train,y_train)
        score = rf.score(X_test,y_test) 
        if (score > max):
            max = score
            nmax=estimator
            
    return max, nmax
leagues = [21518,1729,4769,10257]

# %%
leagues = [21518,1729,4769,10257]
bar_width=0.18
from sklearn.metrics import accuracy_score


for league in leagues:
    dado_aux = dados[dados['league_id'] == league]
    
    limit = dado_aux[['league_id','season']]['season'].unique()
    season = limit[:-1]
    test = dado_aux[dado_aux['season']>= limit[-1]]
    print "League - " + str(league)
    log=[]
    svm=[]
    rdf=[]
    naive=[]
    for s in season:
        train= dado_aux[dado_aux['season']<= s]

        X_train= train[ft]
        y_train = train['Output']
        X_test = test[ft]
        y_test = test['Output']

        log_reg = LogisticRegression()
        log_reg.fit(X_train,y_train)
        #rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
        #rf.fit(X_train,y_train)
        rf_score,rf_estimator = setRF(X_train,y_train,X_test,y_test)
        svc_model = SVC(C=1)
        svc_model.fit(X_train,y_train)
        log.append(log_reg.score(X_test,y_test))
        rdf.append(rf_score)
        svm.append(svc_model.score(X_test,y_test))
        ynaive=[y_train.mode()[0]]*len(y_test)
        naive.append(accuracy_score(y_test,ynaive))
        print rf_estimator
    print "LogReg"
    print log
    print "---\nRF"
    print rdf
    print "---\nSVM"
    print svm
    print "---\nNaive"
    print naive
    plt.figure()
    
    plt.bar(season,log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    
    plt.title('League -'+str(league))
    plt.ylabel('Accuracy')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
# Out:
# League - 21518
# 100
# 1000
# 1000
# 1000
# 1000
# 1000
# 500
# LogReg
# [0.41515151515151516, 0.49090909090909091, 0.53636363636363638, 0.53939393939393943, 0.53333333333333333, 0.52727272727272723, 0.53030303030303028]
# ---
# RF
# [0.53333333333333333, 0.53636363636363638, 0.55151515151515151, 0.55757575757575761, 0.53939393939393943, 0.55454545454545456, 0.56666666666666665]
# ---
# SVM
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# ---
# Naive
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# League - 1729
# 500
# 2000
# 1000
# 2000
# 500
# 2000
# 3000
# LogReg
# [0.45454545454545453, 0.41212121212121211, 0.4212121212121212, 0.41515151515151516, 0.43333333333333335, 0.45454545454545453, 0.46363636363636362]
# ---
# RF
# [0.44545454545454544, 0.43939393939393939, 0.45757575757575758, 0.46969696969696972, 0.48787878787878786, 0.46363636363636362, 0.47878787878787876]
# ---
# SVM
# [0.42727272727272725, 0.42727272727272725, 0.4303030303030303, 0.4303030303030303, 0.4303030303030303, 0.4303030303030303, 0.42727272727272725]
# ---
# Naive
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# League - 4769
# 50
# 1000
# 2000
# 2000
# 500
# 3000
# 3000
# LogReg
# [0.34346504559270519, 0.37689969604863222, 0.42553191489361702, 0.43161094224924013, 0.45288753799392095, 0.45592705167173253, 0.45896656534954405]
# ---
# RF
# [0.45592705167173253, 0.45592705167173253, 0.46200607902735563, 0.47112462006079026, 0.48936170212765956, 0.48328267477203646, 0.48328267477203646]
# ---
# SVM
# [0.42553191489361702, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.43161094224924013, 0.42249240121580545]
# ---
# Naive
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# League - 10257
# 50
# 500
# 2000
# 100
# 1000
# 500
# 1000
# LogReg
# [0.47272727272727272, 0.49090909090909091, 0.47272727272727272, 0.50303030303030305, 0.50303030303030305, 0.51818181818181819, 0.51212121212121209]
# ---
# RF
# [0.5, 0.51818181818181819, 0.53030303030303028, 0.53636363636363638, 0.53636363636363638, 0.54848484848484846, 0.55151515151515151]
# ---
# SVM
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
# ---
# Naive
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]

# %%
import numpy as np
season = [0,1,2,3,4,5,6]
season = np.array(season)
log=[0.41515151515151516, 0.49090909090909091, 0.53636363636363638, 0.53939393939393943, 0.53333333333333333, 0.52727272727272723, 0.53030303030303028]

rdf=[0.53939393939393943, 0.54545454545454541, 0.55454545454545456, 0.55757575757575761, 0.54242424242424248, 0.55151515151515151, 0.56666666666666665]

svm=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]

naive=[0.49090909090909091, 0.50151515151515147, 0.5131313131313131, 0.5083333333333333, 0.50484848484848488, 0.50050505050505045, 0.49393939393939396]
bar_width= 0.2

plt.bar(season,log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
plt.bar(season+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
plt.bar(season+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
plt.bar(season+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')

plt.show()

# %%
for league in leagues:
    dado_aux = dados[dados['league_id'] == league]
    
    limit = dado_aux[['league_id','season']]['season'].unique()
    season = limit[:-1]
    test = dado_aux[dado_aux['season']>= limit[-1]]
    print "League - " + str(league)
    log=[]
    svm=[]
    rdf=[]
    base= season[0]
    xs=[]
    naive=[]
    for i in range(1,len(season)):
        upper= season[i]
        
        dado= dado_aux[dado_aux['season']<= upper]
        train= dado[dado['season']>= base]

        X_train= train[ft]
        y_train = train['Output']
        X_test = test[ft]
        y_test = test['Output']

        aux = str(base) + "-" + str(upper)
        print aux

        log_reg = LogisticRegression()
        log_reg.fit(X_train,y_train)
        #rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
        #rf.fit(X_train,y_train)
        rf_score,rf_estimator = setRF(X_train,y_train,X_test,y_test)
        svc_model = SVC(C=1)
        svc_model.fit(X_train,y_train)
        log.append(log_reg.score(X_test,y_test))
        rdf.append(rf_score)
        svm.append(svc_model.score(X_test,y_test))
        print rf_estimator
        xs.append(str(aux))
        ynaive=[y_train.mode()[0]]*len(y_test)
        naive.append(accuracy_score(y_test,ynaive))
        base = upper
    print "LogReg"
    print log
    print "---\nRF"
    print rdf
    print "---\nSVM"
    print svm
    print "---\nNaive"
    print naive
    plt.figure()
    
    plt.bar(season[:-1],log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season[:-1]+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season[:-1]+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season[:-1]+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    plt.xticks(season[:-1], xs)
    
    plt.title('League -'+str(league))
    plt.ylabel('Accuracy')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
# Out:
# League - 21518
# 0-1
# 1000
# 1-2
# 2000
# 2-3
# 50
# 3-4
# 1000
# 4-5
# 500
# 5-6
# 100
# LogReg
# [0.49090909090909091, 0.52121212121212124, 0.48787878787878786, 0.49393939393939396, 0.44242424242424244, 0.46363636363636362]
# ---
# RF
# [0.53939393939393943, 0.56060606060606055, 0.57878787878787874, 0.54242424242424248, 0.53030303030303028, 0.52727272727272723]
# ---
# SVM
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# ---
# Naive
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# League - 1729
# 0-1
# 50
# 1-2
# 500
# 2-3
# 500
# 3-4
# 1000
# 4-5
# 1000
# 5-6
# 50
# LogReg
# [0.41212121212121211, 0.42727272727272725, 0.42424242424242425, 0.37878787878787878, 0.4212121212121212, 0.46969696969696972]
# ---
# RF
# [0.4303030303030303, 0.46969696969696972, 0.46666666666666667, 0.47272727272727272, 0.47878787878787876, 0.47575757575757577]
# ---
# SVM
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# ---
# Naive
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# League - 4769
# 0-1
# 2000
# 1-2
# 3000
# 2-3
# 500
# 3-4
# 3000
# 4-5
# 2000
# 5-6
# 100
# LogReg
# [0.37689969604863222, 0.40121580547112462, 0.43465045592705165, 0.42857142857142855, 0.43465045592705165, 0.46504559270516715]
# ---
# RF
# [0.46504559270516715, 0.43768996960486323, 0.46200607902735563, 0.46504559270516715, 0.47112462006079026, 0.46808510638297873]
# ---
# SVM
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# ---
# Naive
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# League - 10257
# 0-1
# 1000
# 1-2
# 3000
# 2-3
# 1000
# 3-4
# 1000
# 4-5
# 2000
# 5-6
# 500
# LogReg
# [0.49090909090909091, 0.51515151515151514, 0.48787878787878786, 0.46969696969696972, 0.47575757575757577, 0.45757575757575758]
# ---
# RF
# [0.51212121212121209, 0.52727272727272723, 0.52121212121212124, 0.52727272727272723, 0.53636363636363638, 0.50303030303030305]
# ---
# SVM
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
# ---
# Naive
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]

# %%
for league in leagues:
    dado_aux = dados[dados['league_id'] == league]
    
    limit = dado_aux[['league_id','season']]['season'].unique()
    season = limit[:-1]
    test = dado_aux[dado_aux['season']>= limit[-1]]
    print "League - " + str(league)
    log=[]
    svm=[]
    rdf=[]
    base= season[0]
    xs=[]
    naive=[]
    for i in range(2,len(season)):
        upper= season[i]
        
        dado= dado_aux[dado_aux['season']<= upper]
        train= dado[dado['season']>= base]

        X_train= train[ft]
        y_train = train['Output']
        X_test = test[ft]
        y_test = test['Output']

        aux = str(base) + "-" + str(upper)
        print aux

        log_reg = LogisticRegression()
        log_reg.fit(X_train,y_train)
        #rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
        #rf.fit(X_train,y_train)
        rf_score,rf_estimator = setRF(X_train,y_train,X_test,y_test)
        svc_model = SVC(C=1)
        svc_model.fit(X_train,y_train)
        log.append(log_reg.score(X_test,y_test))
        rdf.append(rf_score)
        svm.append(svc_model.score(X_test,y_test))
        print rf_estimator
        xs.append(str(aux))
        base = upper-1
        ynaive=[y_train.mode()[0]]*len(y_test)
        naive.append(accuracy_score(y_test,ynaive))
    print "LogReg"
    print log
    print "---\nRF"
    print rdf
    print "---\nSVM"
    print svm
    print "---\nNaive"
    print naive
    plt.figure()
    
    plt.bar(season[:-2],log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season[:-2]+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season[:-2]+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season[:-2]+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    
    plt.xticks(season[:-2], xs)
    
    plt.title('League -'+str(league))
    plt.ylabel('Accuracy')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
# Out:
# League - 21518
# 0-2
# 2000
# 1-3
# 2000
# 2-4
# 1000
# 3-5
# 2000
# 4-6
# 100
# LogReg
# [0.53636363636363638, 0.52424242424242429, 0.52424242424242429, 0.49393939393939396, 0.48484848484848486]
# ---
# RF
# [0.55454545454545456, 0.55454545454545456, 0.5636363636363636, 0.52424242424242429, 0.53939393939393943]
# ---
# SVM
# [0.5, 0.5, 0.5, 0.5, 0.5]
# ---
# Naive
# [0.5, 0.5, 0.5, 0.5, 0.5]
# League - 1729
# 0-2
# 50
# 1-3
# 50
# 2-4
# 1000
# 3-5
# 1000
# 4-6
# 100
# LogReg
# [0.4212121212121212, 0.41515151515151516, 0.41515151515151516, 0.44242424242424244, 0.44848484848484849]
# ---
# RF
# [0.45151515151515154, 0.46666666666666667, 0.46666666666666667, 0.46060606060606063, 0.49090909090909091]
# ---
# SVM
# [0.4303030303030303, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# ---
# Naive
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# League - 4769
# 0-2
# 100
# 1-3
# 100
# 2-4
# 2000
# 3-5
# 500
# 4-6
# 1000
# LogReg
# [0.42553191489361702, 0.41945288753799392, 0.44984802431610943, 0.43768996960486323, 0.47720364741641336]
# ---
# RF
# [0.45592705167173253, 0.46200607902735563, 0.46808510638297873, 0.47416413373860183, 0.47112462006079026]
# ---
# SVM
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# ---
# Naive
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# League - 10257
# 0-2
# 500
# 1-3
# 1000
# 2-4
# 3000
# 3-5
# 3000
# 4-6
# 2000
# LogReg
# [0.47272727272727272, 0.50909090909090904, 0.46666666666666667, 0.48484848484848486, 0.48181818181818181]
# ---
# RF
# [0.53030303030303028, 0.53030303030303028, 0.53636363636363638, 0.54848484848484846, 0.53333333333333333]
# ---
# SVM
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
# ---
# Naive
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]

# %%
dado_aux = dados[dados['league_id'] == 21518]
limit = dado_aux[['league_id','season']]['season'].unique()
season = limit[:-1]
test = dado_aux[dado_aux['season']>= limit[-1]]
train = dado_aux[dado_aux['season']<season[-1]]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=3]
train= dado[dado['season']>=2]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
train = dado_aux[dado_aux['season']<=2]
#train= dado[dado['season']>2]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=3000, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)
# Out:
# B365A
# 0.0299838639628
# -----
# B365A
# 0.0278122617687
# -----
# B365A
# 0.0287876885667

# %%
dado_aux = dados[dados['league_id'] == 1729]
limit = dado_aux[['league_id','season']]['season'].unique()
season = limit[:-1]
test = dado_aux[dado_aux['season']>= limit[-1]]
train = dado_aux[dado_aux['season']<season[-1]]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=2000, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=5]
train= dado[dado['season']>=4]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=6]
train= dado[dado['season']>=4]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)
# Out:
# B365H
# 0.0309081827268
# -----
# B365H
# 0.0366993308435
# -----
# B365H
# 0.0355825356547

# %%
dado_aux = dados[dados['league_id'] == 4769]
limit = dado_aux[['league_id','season']]['season'].unique()
season = limit[:-1]
test = dado_aux[dado_aux['season']>= limit[-1]]
train = dado_aux[dado_aux['season']<season[-1]]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=5]
train= dado[dado['season']>=4]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=6]
train= dado[dado['season']>=4]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)
# Out:
# B365H
# 0.0278824203062
# -----
# B365A
# 0.0267561514039
# -----
# B365A
# 0.0283321671343

# %%
dado_aux = dados[dados['league_id'] == 10257]
limit = dado_aux[['league_id','season']]['season'].unique()
season = limit[:-1]
test = dado_aux[dado_aux['season']>= limit[-1]]
train = dado_aux[dado_aux['season']<season[-1]]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=5]
train= dado[dado['season']>=4]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=50, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)

print "-----"
dado = dado_aux[dado_aux['season']<=5]
train= dado[dado['season']>=3]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
rf = RandomForestClassifier(n_estimators=3000, n_jobs=-1)
rf.fit(X_train,y_train)
a=rf.feature_importances_
print ft[a.argmax(axis=0)]
print a.max(axis=0)
# Out:
# B365H
# 0.0315733904779
# -----
# B365A
# 0.0320179266381
# -----
# B365H
# 0.0298287705712

# %%
train = dado_aux[dado_aux['season']<=2]
#train= dado[dado['season']>2]
X_train= train[ft]
y_train = train['Output']
X_test = test[ft]
y_test = test['Output']
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
a = log_reg.coef_
#print ft[a.argmax(axis=0)]
#print a.max(axis=0)
print ft[a[0].argmax(axis=0)]
print a[0].max(axis=0)
print ft[a[1].argmax(axis=0)]
print a[1].max(axis=0)
print ft[a[2].argmax(axis=0)]
print a[2].max(axis=0)
# Out:
# B365H
# 0.409921780906
# ghm_lhm_J1GS
# 0.179153293233
# lam_AVG_GOALS
# 0.523638676418

# %%
n = 1000000.0
p1= ((n/2)/n) * (((n/2)-1)/(n-1)) * ((n/2)/(n-2)) * ((n/2)-1)/(n-3)
p2= ((n/2)/n) * (((n/2)-1)/(n-1)) * (((n/2)-2)/(n-2)) * (((n/2)-3)/(n-3))

p3 = ((n/2)/n) * (((n/2)-1)/(n-1)) * (((n/2)-2)/(n-2)) * (((n/2)-3)/(n-3)) * (((n/2)-4)/(n-4)) * (((n/2)-5)/(n-5)) * (((n/2)-6)/(n-6)) 

print p1
print p2
print p3
# Out:
# 0.0625001250003
# 0.0624996249998
# 0.00781233593816

# %% [markdown]
# Usando as metricas f1 micro e macro

# %%
from sklearn.metrics import f1_score

def setRFf1(X_train,y_train,X_test,y_test):
    n = [50,100,500,1000,2000,3000]
    f1mac = 0
    f1mic = 0
    nmax = 0
    max=0
    
    for estimator in n :
        rf = RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
        rf.fit(X_train,y_train)
        y_pred = rf.predict(X_test) 
        f1_mic = f1_score(y_test, y_pred, average='micro')
        f1_mac = f1_score(y_test, y_pred, average='macro')
        if ( (f1_mic+f1_mac)/2 > max):
            max = (f1_mic+f1_mac)/2
            f1mac = f1_mac
            f1mic= f1_mic
            nmax=estimator
            
    return f1mac,f1mic, nmax

# %%
for league in leagues:
    dado_aux = dados[dados['league_id'] == league]
    
    limit = dado_aux[['league_id','season']]['season'].unique()
    season = limit[:-1]
    test = dado_aux[dado_aux['season']>= limit[-1]]
    print "League - " + str(league)
    log=[]
    svm=[]
    rdf=[]
    log2=[]
    svm2=[]
    rdf2=[]
    naive=[]
    naive2=[]
       
    for s in season:
        train= dado_aux[dado_aux['season']<= s]

        X_train= train[ft]
        y_train = train['Output']
        X_test = test[ft]
        y_test = test['Output']

        log_reg = LogisticRegression()
        log_reg.fit(X_train,y_train)
        #rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
        #rf.fit(X_train,y_train)
        rf_mic,rf_mac,rf_estimator = setRFf1(X_train,y_train,X_test,y_test)
        svc_model = SVC(C=1)
        svc_model.fit(X_train,y_train)
        
        
        logp = log_reg.predict(X_test)
        log.append(f1_score(y_test, logp, average='micro'))
        log2.append(f1_score(y_test, logp, average='macro'))
        
        svmp = svc_model.predict(X_test)
        
        rdf.append(rf_mic)
        rdf2.append(rf_mac)
        svm.append(f1_score(y_test, svmp, average='micro'))
        svm2.append(f1_score(y_test, svmp, average='macro'))
        
        ynaive=[y_train.mode()[0]]*len(y_test)
        naive.append(f1_score(y_test, ynaive, average='micro'))
        naive2.append(f1_score(y_test, ynaive, average='macro'))
        #n=int(y_train.value_counts()[0])
        #n= [n] * len(y_test)
        #print n        
        #print  y_train.value_counts()[0]
        #naive.append(f1_score(y_test, n, average='micro'))
        #naive2.append(f1_score(y_test, n, average='macro'))
        
        print rf_estimator
    print "LogReg"
    print log
    print "---\nRF"
    print rdf
    print "---\nSVM"
    print svm
    print "---\nNaive"
    print naive
    plt.figure()
    
    plt.bar(season,log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    

    plt.title('League -'+str(league))
    plt.ylabel('F1-Micro')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
    
    plt.figure()
    
    plt.bar(season,log2,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season+bar_width,rdf2,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season+(bar_width*2),svm2,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season+(bar_width*3),naive2,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    

    plt.title('League -'+str(league))
    plt.ylabel('F1-Macro')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
# Out:
# League - 21518
# 50
# 50
# 100
# 3000
# 100
# 1000
# 500
# LogReg
# [0.41515151515151516, 0.49090909090909091, 0.53636363636363638, 0.53939393939393943, 0.53333333333333333, 0.52727272727272723, 0.53030303030303028]
# ---
# RF
# [0.41037409321511542, 0.41791995264182374, 0.43281608717406428, 0.40524439471510404, 0.4013500608455069, 0.38955663729786832, 0.40277518570461041]
# ---
# SVM
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# ---
# Naive
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# League - 1729
# 50
# 2000
# 100
# 100
# 1000
# 2000
# 100
# LogReg
# [0.45454545454545453, 0.41212121212121211, 0.4212121212121212, 0.41515151515151516, 0.43333333333333335, 0.45454545454545453, 0.46363636363636362]
# ---
# RF
# [0.37080289540657324, 0.35968803167863644, 0.36746189852311639, 0.38592250212606233, 0.41360501054354321, 0.37806829442738255, 0.41494295177869295]
# ---
# SVM
# [0.42727272727272725, 0.42727272727272725, 0.43030303030303024, 0.43030303030303024, 0.43030303030303024, 0.43030303030303024, 0.42727272727272725]
# ---
# Naive
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# League - 4769
# 3000
# 2000
# 3000
# 500
# 500
# 50
# 100
# LogReg
# [0.34346504559270519, 0.37689969604863216, 0.42553191489361697, 0.43161094224924013, 0.45288753799392095, 0.45592705167173253, 0.45896656534954405]
# ---
# RF
# [0.42495760924763948, 0.38321586721854595, 0.3791825844882597, 0.40112258524241556, 0.40899151025968222, 0.43398579038372481, 0.41052293477666613]
# ---
# SVM
# [0.42553191489361697, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.43161094224924013, 0.42249240121580545]
# ---
# Naive
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# League - 10257
# 2000
# 2000
# 3000
# 3000
# 3000
# 500
# 100
# LogReg
# [0.47272727272727272, 0.49090909090909091, 0.47272727272727272, 0.50303030303030305, 0.50303030303030305, 0.51818181818181819, 0.51212121212121209]
# ---
# RF
# [0.39801610677161631, 0.40267509984272459, 0.41586955203976478, 0.41692748461916018, 0.43387838620374614, 0.43820328458471636, 0.45131986006302949]
# ---
# SVM
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
# ---
# Naive
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]

# %%
bar_width=0.18
for league in leagues:
    dado_aux = dados[dados['league_id'] == league]
    
    limit = dado_aux[['league_id','season']]['season'].unique()
    season = limit[:-1]
    test = dado_aux[dado_aux['season']>= limit[-1]]
    print "League - " + str(league)
    log=[]
    svm=[]
    rdf=[]
    log2=[]
    svm2=[]
    rdf2=[]
    naive=[]
    naive2=[]
    base= season[0]
    xs=[]
    for i in range(1,len(season)):
        upper= season[i]
        
        dado= dado_aux[dado_aux['season']<= upper]
        train= dado[dado['season']>= base]

        X_train= train[ft]
        y_train = train['Output']
        X_test = test[ft]
        y_test = test['Output']

        aux = str(base) + "-" + str(upper)
        print aux

        rf_mic,rf_mac,rf_estimator = setRFf1(X_train,y_train,X_test,y_test)
        svc_model = SVC(C=1)
        svc_model.fit(X_train,y_train)
        
        log_reg = LogisticRegression()
        log_reg.fit(X_train,y_train)
        
        logp = log_reg.predict(X_test)
        log.append(f1_score(y_test, logp, average='micro'))
        log2.append(f1_score(y_test, logp, average='macro'))
        
        svmp = svc_model.predict(X_test)
        
        rdf.append(rf_mic)
        rdf2.append(rf_mac)
        svm.append(f1_score(y_test, svmp, average='micro'))
        svm2.append(f1_score(y_test, svmp, average='macro'))
        
        ynaive=[y_train.mode()[0]]*len(y_test)
        naive.append(f1_score(y_test, ynaive, average='micro'))
        naive2.append(f1_score(y_test, ynaive, average='macro'))
        xs.append(str(aux))
        print rf_estimator
        base = upper
    print "LogReg"
    print log
    print "---\nRF"
    print rdf
    print "---\nSVM"
    print svm
    print "---\nNaive"
    print naive
    plt.figure()
    
    plt.bar(season[:-1],log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season[:-1]+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season[:-1]+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season[:-1]+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    

    plt.title('League -'+str(league))
    plt.ylabel('F1-Micro')
    plt.xlabel('Acumulative Season')
    plt.xticks(season[:-1], xs)
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
    
    plt.figure()
    
    plt.bar(season[:-1],log2,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season[:-1]+bar_width,rdf2,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season[:-1]+(bar_width*2),svm2,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season[:-1]+(bar_width*3),naive2,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    

    plt.title('League -'+str(league))
    plt.ylabel('F1-Macro')
    plt.xlabel('Acumulative Season')
    plt.xticks(season[:-1], xs)
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
# Out:
# League - 21518
# 0-1
# 1000
# 1-2
# 100
# 2-3
# 50
# 3-4
# 100
# 4-5
# 3000
# 5-6
# 500
# LogReg
# [0.49090909090909091, 0.52121212121212124, 0.48787878787878786, 0.49393939393939396, 0.44242424242424244, 0.46363636363636362]
# ---
# RF
# [0.37988122543054376, 0.41415727321524426, 0.4479549858681276, 0.3927341747502468, 0.40239647968655606, 0.41658545179472056]
# ---
# SVM
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# ---
# Naive
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# League - 1729
# 0-1
# 100
# 1-2
# 100
# 2-3
# 50
# 3-4
# 500
# 4-5
# 100
# 5-6
# 3000
# LogReg
# [0.41212121212121211, 0.42727272727272725, 0.42424242424242431, 0.37878787878787878, 0.4212121212121212, 0.46969696969696972]
# ---
# RF
# [0.3918140546368436, 0.39054127932363786, 0.39222580067990692, 0.41357527150210077, 0.39034551922857846, 0.34605727559508886]
# ---
# SVM
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# ---
# Naive
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# League - 4769
# 0-1
# 2000
# 1-2
# 500
# 2-3
# 100
# 3-4
# 1000
# 4-5
# 1000
# 5-6
# 50
# LogReg
# [0.37689969604863216, 0.40121580547112462, 0.43465045592705165, 0.42857142857142855, 0.43465045592705165, 0.46504559270516715]
# ---
# RF
# [0.39198020668558048, 0.35382534223634643, 0.39132149901380675, 0.38482371332820303, 0.40760175324686648, 0.4020039166366231]
# ---
# SVM
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# ---
# Naive
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# League - 10257
# 0-1
# 1000
# 1-2
# 1000
# 2-3
# 1000
# 3-4
# 100
# 4-5
# 2000
# 5-6
# 3000
# LogReg
# [0.49090909090909091, 0.51515151515151514, 0.48787878787878786, 0.46969696969696972, 0.47575757575757577, 0.45757575757575752]
# ---
# RF
# [0.41290927854395348, 0.41645389084078338, 0.41938588381294317, 0.4674002490978188, 0.41850332902964488, 0.42844332352529074]
# ---
# SVM
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
# ---
# Naive
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]

# %%
for league in leagues:
    dado_aux = dados[dados['league_id'] == league]
    
    limit = dado_aux[['league_id','season']]['season'].unique()
    season = limit[:-1]
    test = dado_aux[dado_aux['season']>= limit[-1]]
    print "League - " + str(league)
    log=[]
    svm=[]
    rdf=[]
    log2=[]
    svm2=[]
    rdf2=[]
    naive=[]
    naive2=[]
    base= season[0]
    xs=[]
    for i in range(2,len(season)):
        upper= season[i]
        
        dado= dado_aux[dado_aux['season']<= upper]
        train= dado[dado['season']>= base]

        X_train= train[ft]
        y_train = train['Output']
        X_test = test[ft]
        y_test = test['Output']

        aux = str(base) + "-" + str(upper)
        print aux

        rf_mic,rf_mac,rf_estimator = setRFf1(X_train,y_train,X_test,y_test)
        svc_model = SVC(C=1)
        svc_model.fit(X_train,y_train)
        
        
        logp = log_reg.predict(X_test)
        log.append(f1_score(y_test, logp, average='micro'))
        log2.append(f1_score(y_test, logp, average='macro'))
        
        svmp = svc_model.predict(X_test)
        
        rdf.append(rf_mic)
        rdf2.append(rf_mac)
        svm.append(f1_score(y_test, svmp, average='micro'))
        svm2.append(f1_score(y_test, svmp, average='macro'))
        
        ynaive=[y_train.mode()[0]]*len(y_test)
        naive.append(f1_score(y_test, ynaive, average='micro'))
        naive2.append(f1_score(y_test, ynaive, average='macro'))
        print rf_estimator
        xs.append(str(aux))
        base = upper-1
        
    print "LogReg"
    print log
    print "---\nRF"
    print rdf
    print "---\nSVM"
    print svm
    print "---\nNaive"
    print naive
    plt.figure()
    
    plt.bar(season[:-2],log,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season[:-2]+bar_width,rdf,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season[:-2]+(bar_width*2),svm,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season[:-2]+(bar_width*3),naive,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    
    plt.xticks(season[:-2], xs)
    
    plt.title('League -'+str(league))
    plt.ylabel('F1-Micro')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.figure()
    
    plt.bar(season[:-2],log2,bar_width,alpha=0.8,color='g',label='LogReg',hatch='*')
    plt.bar(season[:-2]+bar_width,rdf2,bar_width,alpha=0.8,color='c',label='RF',hatch='.')
    plt.bar(season[:-2]+(bar_width*2),svm2,bar_width,alpha=0.8,color='b',label='SVM', hatch='//')
    plt.bar(season[:-2]+(bar_width*3),naive2,bar_width,alpha=0.8,color='y',label='Naive', hatch='-')
    
    plt.xticks(season[:-2], xs)
    
    plt.title('League -'+str(league))
    plt.ylabel('F1-Macro')
    plt.xlabel('Acumulative Season')

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.show()
# Out:
# League - 21518
# 0-2
# 50
# 1-3
# 3000
# 2-4
# 2000
# 3-5
# 100
# 4-6
# 3000
# LogReg
# [0.50303030303030305, 0.50303030303030305, 0.50303030303030305, 0.50303030303030305, 0.50303030303030305]
# ---
# RF
# [0.42283965795153405, 0.42059754446366893, 0.40497941056764586, 0.39618062773383844, 0.43058667212698737]
# ---
# SVM
# [0.5, 0.5, 0.5, 0.5, 0.5]
# ---
# Naive
# [0.5, 0.5, 0.5, 0.5, 0.5]
# League - 1729
# 0-2
# 50
# 1-3
# 50
# 2-4
# 1000
# 3-5
# 100
# 4-6
# 100
# LogReg
# [0.3575757575757576, 0.3575757575757576, 0.3575757575757576, 0.3575757575757576, 0.3575757575757576]
# ---
# RF
# [0.37634158237078935, 0.40125484662650673, 0.39667832432514266, 0.38162801229324961, 0.39472003609225176]
# ---
# SVM
# [0.43030303030303024, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# ---
# Naive
# [0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725, 0.42727272727272725]
# League - 4769
# 0-2
# 500
# 1-3
# 50
# 2-4
# 50
# 3-5
# 100
# 4-6
# 50
# LogReg
# [0.35258358662613981, 0.35258358662613981, 0.35258358662613981, 0.35258358662613981, 0.35258358662613981]
# ---
# RF
# [0.38091611196449904, 0.36956469456469448, 0.41991046401975923, 0.42061785323140494, 0.40474056750669551]
# ---
# SVM
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# ---
# Naive
# [0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855]
# League - 10257
# 0-2
# 100
# 1-3
# 3000
# 2-4
# 1000
# 3-5
# 3000
# 4-6
# 100
# LogReg
# [0.45757575757575752, 0.45757575757575752, 0.45757575757575752, 0.45757575757575752, 0.45757575757575752]
# ---
# RF
# [0.42084928245256542, 0.41914786967418544, 0.44478073541373853, 0.43812469317623953, 0.43239283239283238]
# ---
# SVM
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
# ---
# Naive
# [0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453, 0.45454545454545453]
