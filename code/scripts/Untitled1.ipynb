# %%
import shelve
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
import numpy as np
from numpy import random


filename='./shelve/shelve.out'
my_shelf = shelve.open(filename)
for key in my_shelf:
    try:
        globals()[key]=my_shelf[key]
    except:
        #
        print('ERROR shelving: {0}'.format(key))
my_shelf.close()
# Out:
# ERROR shelving: pca_nb_validation
# ERROR shelving: change_season
# ERROR shelving: all_algorithms
# ERROR shelving: sorted_x
# ERROR shelving: out
# ERROR shelving: sf_raw_test
# ERROR shelving: rf_raw_pca
# ERROR shelving: pca_ft_test
# ERROR shelving: sf_gb_h_raw
# ERROR shelving: rank
# ERROR shelving: pca_ft_train
# ERROR shelving: sf_logreg_ft_a
# ERROR shelving: sf_logreg_ft_h
# ERROR shelving: tot
# ERROR shelving: sf_val_h_lda
# ERROR shelving: sf_knn_lda2_h
# ERROR shelving: sf_knn_ft_h
# ERROR shelving: sf_knn_lda2_a
# ERROR shelving: sf_knn_ft_a
# ERROR shelving: sf_logreg_lda2_a
# ERROR shelving: sf_logreg_lda2_h
# ERROR shelving: r
# ERROR shelving: sf_raw_train
# ERROR shelving: target_name
# ERROR shelving: sf_gb_ft
# ERROR shelving: sf_ft_val
# ERROR shelving: nb_raw_lda
# ERROR shelving: pca_raw_train
# ERROR shelving: sf_raw_train_h
# ERROR shelving: sf_knn_ft_lda
# ERROR shelving: sf_gb_a_raw
# ERROR shelving: pvalue
# ERROR shelving: sf_rf_ft
# ERROR shelving: nb_ft_pca
# ERROR shelving: sf_gb_lda2_a
# ERROR shelving: sf_gb_lda2_h
# ERROR shelving: sf_nb_ft_a
# ERROR shelving: sf_nb_ft_h
# ERROR shelving: pca_gb_validation
# ERROR shelving: sf_logreg_a_raw
# ERROR shelving: sf_gb_raw
# ERROR shelving: sf_rf_h_raw
# ERROR shelving: sf_ft_train
# ERROR shelving: nb_chi
# ERROR shelving: sf_ft_a_train
# ERROR shelving: sf_nb_a_raw
# ERROR shelving: sf_nb_raw
# ERROR shelving: pca_raw
# ERROR shelving: nb_raw
# ERROR shelving: sf_test_lda
# ERROR shelving: determine_home_result
# ERROR shelving: rf_ft
# ERROR shelving: pca_raw_test
# ERROR shelving: sf_raw_test_h
# ERROR shelving: sf_raw_test_a
# ERROR shelving: sf_gb_ft_lda
# ERROR shelving: value
# ERROR shelving: n
# ERROR shelving: val_value
# ERROR shelving: selected_ft
# ERROR shelving: sf_rf_a_raw
# ERROR shelving: pca_rf_validation
# ERROR shelving: rf_raw
# ERROR shelving: sf_logreg_ft
# ERROR shelving: sf_val_a_lda
# ERROR shelving: sf_nb_ft
# ERROR shelving: nb_raw_pca
# ERROR shelving: pca_ft_val
# ERROR shelving: rf_ft_pca
# ERROR shelving: sf_gb_ft_a
# ERROR shelving: sf_gb_ft_h
# ERROR shelving: sf_ft_test
# ERROR shelving: sf_logreg_h_raw
# ERROR shelving: pca_knn_validation
# ERROR shelving: sf_nb_h_raw
# ERROR shelving: pca_logreg_validation
# ERROR shelving: sf_raw_train_a
# ERROR shelving: sf_knn_h_raw
# ERROR shelving: train_value
# ERROR shelving: val
# ERROR shelving: sf_logreg_ft_lda
# ERROR shelving: tot_val
# ERROR shelving: sf_rf_ft_lda
# ERROR shelving: nb_ft_lda
# ERROR shelving: rf_chi
# ERROR shelving: pca_ft
# ERROR shelving: sf_logreg_raw
# ERROR shelving: test_value
# ERROR shelving: sf_ft_a_val
# ERROR shelving: nb_raw_chi
# ERROR shelving: test
# ERROR shelving: sf_rf_lda2_h
# ERROR shelving: sql
# ERROR shelving: sf_train_h_lda
# ERROR shelving: sf_rf_lda2_a
# ERROR shelving: tot_train

# %%
globals()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     670                 type_pprinters=self.type_printers,
#     671                 deferred_pprinters=self.deferred_printers)
# --> 672             printer.pretty(obj)
#     673             printer.flush()
#     674             return stream.getvalue()
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     366                 if cls in self.type_pprinters:
#     367                     # printer registered in self.type_pprinters
# --> 368                     return self.type_pprinters[cls](obj, self, cycle)
#     369                 else:
#     370                     # deferred printer
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/site-packages/IPython/lib/pretty.pyc in inner(obj, p, cycle)
#     622             p.pretty(key)
#     623             p.text(': ')
# --> 624             p.pretty(obj[key])
#     625         p.end_group(step, end)
#     626     return inner
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/UserDict.pyc in __repr__(self)
#     203             return default
#     204     def __repr__(self):
# --> 205         return repr(dict(self.iteritems()))
#     206     def __cmp__(self, other):
#     207         if other is None:
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/UserDict.pyc in iteritems(self)
#     141     # third level takes advantage of second level definitions
#     142     def iteritems(self):
# --> 143         for k in self:
#     144             yield (k, self[k])
#     145     def iterkeys(self):
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/UserDict.pyc in __iter__(self)
#     128     # second level definitions support higher levels
#     129     def __iter__(self):
# --> 130         for k in self.keys():
#     131             yield k
#     132     def has_key(self, key):
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/shelve.pyc in keys(self)
#      99
#     100     def keys(self):
# --> 101         return self.dict.keys()
#     102
#     103     def __len__(self):
#
# /home/felipef/anaconda2/envs/gl-env/lib/python2.7/shelve.pyc in closed(self, *args)
#      77
#      78     def closed(self, *args):
# ---> 79         raise ValueError('invalid operation on closed shelf')
#      80     __getitem__ = __setitem__ = __delitem__ = keys = closed
#      81
#
# ValueError: invalid operation on closed shelf
